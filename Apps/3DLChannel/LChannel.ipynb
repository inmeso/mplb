# %%
# Add the path where the PostProcess.py
# Replace MPLBDir with your own path
import sys
sys.path.append("MPLBDir/Src")
from PostProcess import ReadBlockData
from PostProcess import SliceVectorPlot,SliceContourPlot
import numpy as np
import matplotlib.pyplot as plt
# Out:
# 2

# %%
variables=[{'name':'rho'},{'name':'u'},{'name':'v'},{'name':'w'},{'name':'NodeType_Fluid'},{'name':'CoordinateXYZ','len':3}]
top = ReadBlockData("3DLChannel_Top_T5000.h5",variables)
middle = ReadBlockData("3DLChannel_Middle_T5000.h5",variables)
right = ReadBlockData("3DLChannel_Right_T5000.h5",variables)
# Out:
# Reading  {'name': 'rho'} ...
# Reading  {'name': 'u'} ...
# Reading  {'name': 'v'} ...
# Reading  {'name': 'w'} ...
# Reading  {'name': 'NodeType_Fluid'} ...
# Reading  {'name': 'CoordinateXYZ', 'len': 3} ...
# Reading  {'name': 'rho'} ...
# Reading  {'name': 'u'} ...
# Reading  {'name': 'v'} ...
# Reading  {'name': 'w'} ...
# Reading  {'name': 'NodeType_Fluid'} ...
# Reading  {'name': 'CoordinateXYZ', 'len': 3} ...
# Reading  {'name': 'rho'} ...
# Reading  {'name': 'u'} ...
# Reading  {'name': 'v'} ...
# Reading  {'name': 'w'} ...
# Reading  {'name': 'NodeType_Fluid'} ...
# Reading  {'name': 'CoordinateXYZ', 'len': 3} ...

# %%
SliceVectorPlot(top,['u','v','w'],['z',16],8)
SliceVectorPlot(middle,['u','v','w'],['z',16],8)
SliceVectorPlot(right,['u','v','w'],['z',16],8)

# %%
SliceContourPlot(top,'rho',['z',16],20,8)
SliceContourPlot(middle,'rho',['z',16],20,8)
SliceContourPlot(right,'rho',['z',16],20,8)
